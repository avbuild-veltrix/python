# %%
lamda_square = lambda x:x**2

# %%
lamda_square(9)
# Out:
# 81

# %%
lamda_square(8)
# Out:
# 64

# %%
add = lambda x,y:x+y
add(9,8)
# Out:
# 17

# %%
even = lambda x:x%2==0
even(9)
# Out:
# False

# %%
x = ["Data Science","Python","C++"]
sorted(x)
# Out:
# ['C++', 'Data Science', 'Python']

# %%
le = lambda d: len(d)####Working fine in lambda function file
le('kartik')
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 le = lambda d: len(d)
# ----> 2 le('kartik')
#
# Cell In[18], line 1, in <lambda>(d)
# ----> 1 le = lambda d: len(d)
#       2 le('kartik')
#
# Cell In[10], line 1, in <lambda>(x)
# ----> 1 len = lambda x:len(x)
#       2 len("Kartik")
#
# Cell In[10], line 1, in <lambda>(x)
# ----> 1 len = lambda x:len(x)
#       2 len("Kartik")
#
#     [... skipping similar frames: <lambda> at line 1 (2973 times)]
#
# Cell In[10], line 1, in <lambda>(x)
# ----> 1 len = lambda x:len(x)
#       2 len("Kartik")
#
# RecursionError: maximum recursion depth exceeded

# %%
sorted(x, key= lambda x: len(x))####Working fine in lambda function file
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 sorted(x, key= lambda x: len(x))
#
# Cell In[21], line 1, in <lambda>(x)
# ----> 1 sorted(x, key= lambda x: len(x))
#
# Cell In[10], line 1, in <lambda>(x)
# ----> 1 len = lambda x:len(x)
#       2 len("Kartik")
#
# Cell In[10], line 1, in <lambda>(x)
# ----> 1 len = lambda x:len(x)
#       2 len("Kartik")
#
#     [... skipping similar frames: <lambda> at line 1 (2973 times)]
#
# Cell In[10], line 1, in <lambda>(x)
# ----> 1 len = lambda x:len(x)
#       2 len("Kartik")
#
# RecursionError: maximum recursion depth exceeded

# %%
help(map)
# Out:
# Help on class map in module builtins:
#
# class map(object)
#  |  map(function, iterable, /, *iterables)
#  |
#  |  Make an iterator that computes the function using arguments from
#  |  each of the iterables.  Stops when the shortest iterable is exhausted.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(self, /)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
def sq(n):
    return n**2

# %%
l = [1,2,4,5,6,7,8,9]

# %%
list(map(sq,l))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 list(map(sq,l))
#
# TypeError: 'map' object is not callable
