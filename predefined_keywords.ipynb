# %%
print("Hello World!")
# Out:
# Hello World!

# %%
a =3

# %%
a
# Out:
# 3

# %%
#Variables are identifiers that are used to store data in a program.
b = 5
b
# Out:
# 5

# %%
#variables are reserved memory locations to store values. In other words, a variable in a python program gives data to the computer for processing.
c = "Aviii"
c
# Out:
# 'Aviii'

# %%
b = 5.4
b
# Out:
# 5.4

# %%
b = 5
b
# Out:
# 5

# %%
b + 5
# Out:
# 10

# %%
c
# Out:
# 'Aviii'

# %%
type(c)
# Out:
# str

# %%
print(type(c))
# Out:
# <class 'str'>

# %%
a = 3
type(a)
# Out:
# int

# %%
type(b)
# Out:
# int

# %%
s = True
type(s)
# Out:
# bool

# %%
True - False
# Out:
# 1

# %%
False + True
# Out:
# 1

# %%
False - True
# Out:
# -1

# %%
True - True
# Out:
# 0

# %%
False / True
# Out:
# 0.0

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
f= None
type(f)
# Out:
# NoneType

# %%
#Complex numbers
x = 3 + 5j
type(x)
# Out:
# complex

# %%
x.real
# Out:
# 3.0

# %%
x.imag
# Out:
# 5.0

# %%
#Rules for defining variables
#1. Variable names must begin with a letter (a - z, A - Z) or an underscore (_)
#2. A variable name cannot start with a number (0 - 9)
#3. A variable name can only contain alpha-numeric characters and underscores (A - Z, a - z, 0 - 9, and _ )
#4. Variable names are case-sensitive (age, Age and AGE are three different variables)

# %%
abc = 5
abc
# Out:
# 5

# %%
location = 'Ghazipur'
location
# Out:
# 'Ghazipur'

# %%
__name = "Aviii"
__name
# Out:
# 'Aviii'

# %%
data_science = "Data Science"
data_science
# Out:
# 'Data Science'

# %%
#Comments in Python

# This is a single line comment

# %%
a = 5 # This is a comment after a statement
a
# Out:
# 5

# %%
#multiple line comment
''' 
jnjnhbdc
jndjndj
jndjndj
'''
# Out:
# ' \njnjnhbdc\njndjndj\njndjndj\n'

# %%
"""
This is a multiple line comment
jnjnhbdc    
jndjndj
"""
a = 5
a
# Out:
# 5

# %%
print("Hello World!")
# --- IGNORE ---
# Out:
# Hello World!

# %%
#Keywords in Python >> 
# and       del       from      None      True
# as        elif      global    nonlocal  try   
# assert    else      if        not       while
# break     except    import    or        with
# class     finally   in        pass      yield
# continue  for       is        raise
# --- IGNORE ---

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
v = 5
if v > 5:
    print("Aviii")
else:
    print("Data Science")
# Out:
# Data Science

# %%
v = 5
if v == 5:
    print("Aviii")
else:
    print("Data Science")
# Out:
# Aviii

# %%
#Input and Output in Python
name = input("Enter your name: ")
name

# %%
name = input("Enter your name: ")
print(f("Hello " + name))
# Out:
# Hello

# %%
#Type Casting in Python
#Type casting is the conversion of one data type to another data type.
name = "Aviii"
type(name)
# Out:
# str

# %%
a = "3.5"
type(a)
# Out:
# str

# %%
type(float(a))
# Out:
# float

# %%
int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 int(a)
#
# ValueError: invalid literal for int() with base 10: '3.5'

# %%
float(a)
# Out:
# 3.5

# %%
str(a)
# Out:
# '3.5'

# %%
A = 10
A
# Out:
# 10

# %%
a
# Out:
# '3.5'

# %%
#Variables should be keywords

print("Hello World!")
# Out:
# Hello World!

# %%
#print = "Ajay"

# %%
print("Hello World!")
# Out:
# Hello World!
