# %%
#string is a sequence of character< represent and manipulate textual data

# %%
chr(103)
# Out:
# 'g'

# %%
char = 'A'

# %%
ord(char)
# Out:
# 65

# %%
chr(65)
# Out:
# 'A'

# %%
#UNICODE REPRESENTATION

# %%
'\u03A9'
# Out:
# 'Ω'

# %%
'\u0374'
# Out:
# 'ʹ'

# %%
'\u0974'
# Out:
# 'ॴ'

# %%
'\u0973'
# Out:
# 'ॳ'

# %%
'\u03A3'
# Out:
# 'Σ'

# %%
#string 
string1 = "Kartik"
string1
# Out:
# 'Kartik'

# %%
type(string1)
# Out:
# str

# %%
A = """I'm a student"""
A
# Out:
# "I'm a student"

# %%
B = 'Hii kartik "How are you?"'
B
# Out:
# 'Hii kartik "How are you?"'

# %%
'''I'm a student
I study in pwskills
And I'm a data scientist'''
# Out:
# "I'm a student\nI study in pwskills\nAnd I'm a data scientist"

# %%
#concatenation of string>> combination of two string

# %%
"Hello" + " World"
# Out:
# 'Hello World'

# %%
String1 = 'Hello'
String2 = 'World'
String1 + ", " + String2
# Out:
# 'Hello, World'

# %%
"string" + ">>" + "concatenation"
# Out:
# 'string>>concatenation'

# %%
"string" + " >$ " + "concatenation"
# Out:
# 'string >$ concatenation'

# %%
#Slicing of string

# %%
A = 'Kartik'
A
# Out:
# 'Kartik'

# %%
A[0]
# Out:
# 'K'

# %%
A[1]
# Out:
# 'a'

# %%
A[2]
# Out:
# 'r'

# %%
A[3]
# Out:
# 't'

# %%
A[4]
# Out:
# 'i'

# %%
A[5]
# Out:
# 'k'

# %%
A[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 A[6]
#
# IndexError: string index out of range

# %%
string1 = 'I am a good student'
string1
# Out:
# 'I am a good student'

# %%
string1[2]
# Out:
# 'a'

# %%
string1[0:-5]
# Out:
# 'I am a good st'

# %%
string1[0:]
# Out:
# 'I am a good student'

# %%
string1[-1:0]
# Out:
# ''

# %%
string1[1:-10]
# Out:
# ' am a go'

# %%
string2 = 'Hello World'

# %%
string2[::-1]
# Out:
# 'dlroW olleH'

# %%
s = 'pwskills'
s[0]
# Out:
# 'p'

# %%
s
# Out:
# 'pwskills'

# %%
#no. of chars

# %%
len(s)
# Out:
# 8

# %%
#string is immutable but it can be modified

# %%
s = "I'm a student"
s
# Out:
# "I'm a student"

# %%
s.replace("student","TEACHER")
# Out:
# "I'm a TEACHER"

# %%
#use cases

# %%
address = "123 Suhana apt, Bilandpur Gorakhpur"
address.replace("apt","apartment")
# Out:
# '123 Suhana apartment, Bilandpur Gorakhpur'

# %%
text = "BRB,TTYL,LOL"
text.replace("BRB","Be right back").replace("TTYL","talk to you later").replace("LOL","laughing out loud")
# Out:
# 'Be right back,talk to you later,laughing out loud'

# %%
text = "Hello World"
text.lower()
# Out:
# 'hello world'

# %%
text.upper()
# Out:
# 'HELLO WORLD'

# %%
text.title()
# Out:
# 'Hello World'

# %%
text = "I'm a student"
text.swapcase()
# Out:
# "i'M A STUDENT"

# %%
text.capitalize()
# Out:
# "I'm a student"

# %%
#string searching
sent = "I am a student at pwskills"
"am" in sent
# Out:
# True

# %%
search_word = "am"
if search_word in sent:
    print("The search_word is present")
else:
    print("Not present")
# Out:
# The search_word is present

# %%
email = 'kartik@1234'
if "@" in email:
    print("Valid email")
else:
    print("invalid")
# Out:
# Valid email

# %%
 document = "some_file.pdf"
if "pdf" in document:
    print("Its a pdf file")
else:
    print("It is not a pdf file")
# Out:
# Its a pdf file

# %%
#string comparision
str1 = "hello"
str2 = "HELLO"
str1 == str2
# Out:
# False

# %%
str1 = "hello"
str2 = "HELLO"
str1.upper() == str2
# Out:
# True

# %%
str1 = "hello"
str2 = "HELLO"
str1 == str2.lower()
# Out:
# True

# %%
reg_username = ["pw", "PW", "pW"]
new_user = "PW1"
if new_user in reg_username:
    print("already in use")
else:
    print("username is avilable")
# Out:
# username is avilable

# %%
product_code = "P123"
scanned_code= input("scan the product code")
if product_code == scanned_code:
    print("The price is 100")
else:
    print("Talk to receptionist")
# Out:
# scan the product code ACV
# Talk to receptionist

# %%
name = ["Kartik","Avinash","Indar"]
sorted(name)
# Out:
# ['Avinash', 'Indar', 'Kartik']

# %%
#Most common string operations
input_str = "                         avi                "
input_str
# Out:
# '                         avi                '

# %%
input_str.strip()
# Out:
# 'avi'

# %%
row = "Apple      "
row
# Out:
# 'Apple      '

# %%
row.strip()
# Out:
# 'Apple'

# %%
#string splitting
data = "Ajay, DS, teacher"
data
# Out:
# 'Ajay, DS, teacher'

# %%
Teacher_info = data.split(',')
Teacher_info
# Out:
# ['Ajay', ' DS', ' teacher']

# %%
name = Teacher_info[0]
Subject = Teacher_info[1]
designation = Teacher_info[2]

# %%
name
# Out:
# 'Ajay'

# %%
Subject
# Out:
# ' DS'

# %%
designation
# Out:
# ' teacher'

# %%
#escape sequences >> special combination of characters used within a string
address = """123, ddugu,
gkp,
up"""

# %%
address
# Out:
# '123, ddugu,\ngkp,\nup'

# %%
print(address) #\n >> to insert a new line chraracter
# Out:
# 123, ddugu,
# gkp,
# up

# %%
#\t escape character \t >> tab
table = "Name\tAge\tGrade\nKartik\t20\tX\nAnam\t19\tX"
print(table)
# Out:
# Name	Age	Grade
# Kartik	20	X
# Anam	19	X

# %%
file_path = "C:\\USERS\\DOWNLOADS\\FILES.txt"
file_path
# Out:
# 'C:\\USERS\\DOWNLOADS\\FILES.txt'

# %%
#\' single quote escape
str1 = 'I can\'t believe it\'s Friday'
str1
# Out:
# "I can't believe it's Friday"

# %%
#carriage return \r >> moves the cursor to the begginig of line
print("Hello, I am \rKartik and I am going to Mathura")
# Out:
# Kartik and I am going to Mathura

# %%
#string formatting >> creating string with placeholder for variables
print("My name is Ajay")
# Out:
# My name is Ajay

# %%
print("My name is Ajay")
print("My name is Kartik")
print("My name is Anam")
# Out:
# My name is Ajay
# My name is Kartik
# My name is Anam

# %%
name = input("Tell me your name : ")
greetings = f"Hello {name}, how are you?"
print(greetings)
# Out:
# Tell me your name :  Kartik
# Hello Kartik, how are you?

# %%
#string formatting
name = "PW Skills"
greeting = "Hello %s, wish you a wonderful day"%name
print(greeting)
# Out:
# Hello PW Skills, wish you a wonderful day

# %%
#.format
template = "Hello, {} welcome to {} "
message = template.format("Anam","Data Science")
print(message)
# Out:
# Hello, Anam welcome to Data Science

# %%
#f string (formatted string literals)
course = "pw data + frontend"
duration = 4
print(f"My course is {course} and its duration is {duration} years.")
# Out:
# My course is pw data + frontend and its duration is 4 years.

# %%
user_name = "Kartik"
post_date = "2024-06-03"

print(f"Hello user, {user_name}, today is {post_date} post.")
# Out:
# Hello user, Kartik, today is 2024-06-03 post.

# %%
celsius = 30
f"{celsius} is equals to {(celsius * 9/5)+32}F"
# Out:
# '30 is equals to 86.0F'

# %%
str2 = 'pwskills'
str2.startswith('p')
# Out:
# True

# %%
str2.startswith("P")
# Out:
# False

# %%
str2.endswith("P")
# Out:
# False

# %%
str2.endswith("s")
# Out:
# True

# %%
a = "123asdf"
a.isalnum()
# Out:
# True

# %%
a = "123"
a.isalnum()
# Out:
# True

# %%
a = 123
a.isalnum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 2
#       1 a = 123
# ----> 2 a.isalnum()
#
# AttributeError: 'int' object has no attribute 'isalnum'

# %%
s = 'pwskills'
print(s)
count = 0
for i in s:
    print(i)
    count = count + 1
print(count)
# Out:
# pwskills
# p
# w
# s
# k
# i
# l
# l
# s
# 8
