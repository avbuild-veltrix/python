# %%
a = 6
a
# Out:
# 6

# %%
#In the memory, a memory block is created with reference name a and value
a
# Out:
# 6

# %%
b = "Kartik"
b
# Out:
# 'Kartik'

# %%
b[-1::]
# Out:
# 'k'

# %%
b[::-1]
# Out:
# 'kitraK'

# %%
b[-2]
# Out:
# 'i'

# %%
#Another type of data container
list_container = [1,2,3,4,5,6,4+5j,'Avi',True,False]
list_container
# Out:
# [1, 2, 3, 4, 5, 6, (4+5j), 'Avi', True, False]

# %%
list_container[0]
# Out:
# 1

# %%
list_container[4]
# Out:
# 5

# %%
list_container[-8]
# Out:
# 3

# %%
type(list_container)
# Out:
# list

# %%
list_container[9]
# Out:
# False

# %%
list_container[-10]
# Out:
# 1

# %%
list_container[-3]
# Out:
# 'Avi'

# %%
list_container[-12]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 list_container[-12]
#
# IndexError: list index out of range

# %%
#Mutability
list_container[7]
# Out:
# 'Avi'

# %%
list_container[7] = "Kartik"
list_container
# Out:
# [1, 2, 3, 4, 5, 6, 'Kartik', 'Kartik', True, False]

# %%
list_container[7] = "Kartik"

# %%
list_container[6] = 6 + 6j
list_container
# Out:
# [1, 2, 3, 4, 5, 6, (6+6j), 'Kartik', True, False]

# %%
b = "PW Skills"
b
# Out:
# 'PW Skills'

# %%
b[0] = 'k'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 b[0] = 'k'
#
# TypeError: 'str' object does not support item assignment
