# %%
#sets

# %%
S = {"red", "orange"}

# %%
S
# Out:
# {'orange', 'red'}

# %%
type(S)
# Out:
# set

# %%
S = {"red", "orange", "red", "orange", "blue", "pink"}
S
# Out:
# {'blue', 'orange', 'pink', 'red'}

# %%
s = {1,2,3,4,5,6,"a","d","s"}

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6, 'a', 'd', 's'}

# %%
print(s, end= " ")
# Out:
# {1, 2, 3, 4, 5, 6, 'a', 's', 'd'}

# %%
s.add("Kartik")
s
# Out:
# {1, 2, 3, 4, 5, 6, 'Kartik', 'a', 'd', 's'}

# %%
s.remove("Kartik")
s
# Out:
# {1, 2, 3, 4, 5, 6, 'a', 'd', 's'}

# %%
#use cases of sets >> to get unique elements

# %%
grocery_list = {"banana", "apple", "egg", "mango", "egg", "banana"}
grocery_list
# Out:
# {'apple', 'banana', 'egg', 'mango'}

# %%
#dictonaries>> stores the data in key-value pair

# %%
my_dict = {}

# %%
type(my_dict)
# Out:
# dict

# %%
my_dict = {"course" : "data science", "duration":200}
my_dict
# Out:
# {'course': 'data science', 'duration': 200}

# %%
my_dict[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 my_dict[1]
#
# KeyError: 1

# %%
#use cases
phonebook = {"dad" : 1234, "Mom" : 1452}
phonebook
# Out:
# {'dad': 1234, 'Mom': 1452}

# %%
phonebook["dad"]
# Out:
# 1234

# %%
phonebook["Mom"]
# Out:
# 1452

# %%
phonebook = {"dad" : 1234, "Mom" : 1452, "dad" : 1598753}
phonebook
# Out:
# {'dad': 1598753, 'Mom': 1452}

# %%
phonebook["dad"]
# Out:
# 1598753

# %%
rest_menu = {"paneer_kofta" : 480, "chicken_handi" : 590}

# %%
rest_menu
# Out:
# {'paneer_kofta': 480, 'chicken_handi': 590}

# %%
rest_menu["paneer_kofta"]
# Out:
# 480

# %%
rest_menu["paneer_kofta"] = 790

# %%
rest_menu
# Out:
# {'paneer_kofta': 790, 'chicken_handi': 590}

# %%
phonebook["dad"] = "I have taken a new number, but I will not tell you"

# %%
phonebook
# Out:
# {'dad': 'I have taken a new number, but I will not tell you', 'Mom': 1452}

# %%
 rest_menu
# Out:
# {'paneer_kofta': 790, 'chicken_handi': 590}

# %%
rest_menu.keys
# Out:
# <function dict.keys>

# %%
rest_menu.keys()
# Out:
# dict_keys(['paneer_kofta', 'chicken_handi'])

# %%
rest_menu.values()
# Out:
# dict_values([790, 590])

# %%
from array import array

# %%
#array is similar to list>> but is store homogeneous data

# %%
array('i', [1,2,3,4])
# Out:
# array('i', [1, 2, 3, 4])

# %%
type(array('i', [1,2,3,4]))
# Out:
# array.array
