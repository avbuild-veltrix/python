# %%
#Tuplesare orderes collections of elements, eterioeneous
#Tuples are immutable

# %%
t = ()

# %%
type(t)
# Out:
# tuple

# %%
t = ("Anam","Avi","Indar","Najar",1,2.5,5+9j)

# %%
t
# Out:
# ('Anam', 'Avi', 'Indar', 'Najar', 1, 2.5, (5+9j))

# %%
t[0]
# Out:
# 'Anam'

# %%
t[-1]
# Out:
# (5+9j)

# %%
#Tuples are immutable

# %%
t[5]
# Out:
# 2.5

# %%
t[5] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 t[5] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
empid = (1,2,3,4,5,6)

# %%
empid
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#Use> Use tuples as a data structure where you do not want to modify te data

# %%
tuple1 = ('Anam', 'Avi', 'Indar', 'Najar', 1,1,2,1,2,1,2,5,4,8,9,6,2,4,2tuple1.count1(),5,5,2, 2.5,(5+9j))
tuple1.count(2)
# Out:
# 6

# %%
tuple1.count(2)
# Out:
# 6

# %%
tuple1.count(5)
# Out:
# 3

# %%
tuple1.index(2)
# Out:
# 6

# %%
print(tuple1*2)
# Out:
# ('Anam', 'Avi', 'Indar', 'Najar', 1, 1, 2, 1, 2, 1, 2, 5, 4, 8, 9, 6, 2, 4, 2, 5, 5, 2, 2.5, (5+9j), 'Anam', 'Avi', 'Indar', 'Najar', 1, 1, 2, 1, 2, 1, 2, 5, 4, 8, 9, 6, 2, 4, 2, 5, 5, 2, 2.5, (5+9j))

# %%
tuple1[0:5]
# Out:
# ('Anam', 'Avi', 'Indar', 'Najar', 1)

# %%
tuple[0:0:-1]
# Out:
# tuple[slice(0, 0, -1)]

# %%
tuple[::-1]
# Out:
# tuple[slice(None, None, -1)]

# %%
tuple1[0:0:-1]
# Out:
# ()

# %%
tuple1[::-1]
# Out:
# ((5+9j),
#  2.5,
#  2,
#  5,
#  5,
#  2,
#  4,
#  2,
#  6,
#  9,
#  8,
#  4,
#  5,
#  2,
#  1,
#  2,
#  1,
#  2,
#  1,
#  1,
#  'Najar',
#  'Indar',
#  'Avi',
#  'Anam')

# %%
for i in tuple1:
    print(i)
# Out:
# Anam
# Avi
# Indar
# Najar
# 1
# 1
# 2
# 1
# 2
# 1
# 2
# 5
# 4
# 8
# 9
# 6
# 2
# 4
# 2
# 5
# 5
# 2
# 2.5
# (5+9j)

# %%
for i in tuple1:
    print(i, type(i))
# Out:
# Anam <class 'str'>
# Avi <class 'str'>
# Indar <class 'str'>
# Najar <class 'str'>
# 1 <class 'int'>
# 1 <class 'int'>
# 2 <class 'int'>
# 1 <class 'int'>
# 2 <class 'int'>
# 1 <class 'int'>
# 2 <class 'int'>
# 5 <class 'int'>
# 4 <class 'int'>
# 8 <class 'int'>
# 9 <class 'int'>
# 6 <class 'int'>
# 2 <class 'int'>
# 4 <class 'int'>
# 2 <class 'int'>
# 5 <class 'int'>
# 5 <class 'int'>
# 2 <class 'int'>
# 2.5 <class 'float'>
# (5+9j) <class 'complex'>

# %%
t1 = (1,2,5,4,7,9,5165,454,1545,2,141554)
max(t1)
# Out:
# 141554

# %%
min(t1)
# Out:
# 1

# %%
t2 = (1014,965,784,105,258,144)
t2
# Out:
# (1014, 965, 784, 105, 258, 144)

# %%
t1
# Out:
# (1, 2, 5, 4, 7, 9, 5165, 454, 1545, 2, 141554)

# %%
t3 = (t1,t2)

# %%
t3
# Out:
# ((1, 2, 5, 4, 7, 9, 5165, 454, 1545, 2, 141554),
#  (1014, 965, 784, 105, 258, 144))

# %%
type(t3)
# Out:
# tuple

# %%
del(t3)

# %%
t3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 t3
#
# NameError: name 't3' is not defined

# %%
t1
# Out:
# (1, 2, 5, 4, 7, 9, 5165, 454, 1545, 2, 141554)

# %%
t2
# Out:
# (1014, 965, 784, 105, 258, 144)

# %%
len(t1)
# Out:
# 11

# %%
len(t2)
# Out:
# 6

# %%
1 in t1
# Out:
# True

# %%
'Anam' in t1
# Out:
# False

# %%
2 in t2
# Out:
# False

# %%
2 in t1
# Out:
# True

# %%
#Combine two tuples
t1+t2
# Out:
# (1, 2, 5, 4, 7, 9, 5165, 454, 1545, 2, 141554, 1014, 965, 784, 105, 258, 144)

# %%
#Sets>> Unordered and unique collections of elements
#It does not allow any duplicate any elements

# %%
s = {}
type(s)
# Out:
# dict

# %%
s = {1}
type(s)
# Out:
# set

# %%
s = {1,2,3,5,4,6,"Avi", "Avi","Avi","Anam"}
s
# Out:
# {1, 2, 3, 4, 5, 6, 'Anam', 'Avi'}
