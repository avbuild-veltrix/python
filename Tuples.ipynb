# %%
#Tuples are immutable

# %%
point = (2,3)
point
# Out:
# (2, 3)

# %%
type(point)
# Out:
# tuple

# %%
point[1]
# Out:
# 3

# %%
point[1] = "Kartik"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 point[1] = "Kartik"
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Use case >> adhar card >> Employee I'd >>

# %%
t = (1,2,3,4,5, "Kartik", True, False, (3 + 5j))

# %%
t
# Out:
# (1, 2, 3, 4, 5, 'Kartik', True, False, (3+5j))

# %%
type(t[-1])
# Out:
# complex

# %%
box1 = ("a", "b")
box2 = ("c","d")
choc_box =
